# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ds_salaries.csv")
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df[~(df['remote_ratio'] == 0)]
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 2             2       2020               SE              FT
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# 6             6       2020               SE              FT
# 7             7       2020               MI              FT
# ..          ...        ...              ...             ...
# 599         599       2022               MI              FT
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 2            Big Data Engineer     85000             GBP         109024
# 4    Machine Learning Engineer    150000             USD         150000
# ...

# %%
average = df['remote_ratio'].mean()
average
# Out:
# 70.92257001647447

# %%
df['remote_ratio'] = df['remote_ratio'].replace(to_replace=0, value = average)
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...
